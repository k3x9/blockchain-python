# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
X = np.array([[1, 2, 1, 1],
 [2, 2, 1, 2],
 [3, 2, 1, 2],
 [4, 2, 1, 2],
 [5, 2, 1, 2]])

y = np.array([1, 1, 1, 1, 1])

model = LogisticRegression()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       7 y = np.array([1, 1, 1, 1, 1])
#       9 model = LogisticRegression()
# ---> 10 model.fit(X, y)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1301, in LogisticRegression.fit(self, X, y, sample_weight)
#    1299 classes_ = self.classes_
#    1300 if n_classes < 2:
# -> 1301     raise ValueError(
#    1302         "This solver needs samples of at least 2 classes"
#    1303         " in the data, but the data contains only one"
#    1304         " class: %r" % classes_[0]
#    1305     )
#    1307 if len(self.classes_) == 2:
#    1308     n_classes = 1
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 1
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# ...
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
import psutil
cpu_usage = psutil.cpu_percent(interval=1)
per_core_usage = psutil.cpu_percent(interval=1, percpu=True)
physical_cores = psutil.cpu_count(logical=False)
logical_cpus = psutil.cpu_count(logical=True)
cpu_freq = psutil.cpu_freq()
load_avg = psutil.getloadavg()

# %%
s = set()
s.add(1)
s.add(2)
s.index(1)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 s.add(1)
#       3 s.add(2)
# ----> 4 s.index(1)
#
# AttributeError: 'set' object has no attribute 'index'
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ...
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py", line 132, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# Generate a synthetic dataset
X, y = make_classification(n_samples=100, n_features=10, random_state=42)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Get the probabilities for the test set
probabilities = model.predict_proba(X_test)

# The output probabilities are for each class
# probabilities[:, 1] gives the probability of the positive class
print("Probabilities:\n", probabilities)
# Out:
# Probabilities:
#  [[7.49632742e-01 2.50367258e-01]
#  [5.71492961e-02 9.42850704e-01]
#  [8.47383467e-03 9.91526165e-01]
#  [3.84386602e-02 9.61561340e-01]
#  [2.79853023e-02 9.72014698e-01]
#  [9.64640318e-01 3.53596817e-02]
#  [9.65369374e-01 3.46306260e-02]
#  [2.13024820e-01 7.86975180e-01]
#  [2.27546362e-01 7.72453638e-01]
#  [1.81401566e-01 8.18598434e-01]
#  [9.87298049e-01 1.27019510e-02]
#  [1.84390109e-03 9.98156099e-01]
#  [1.11638160e-03 9.98883618e-01]
#  [9.98846835e-01 1.15316489e-03]
#  [3.19528899e-03 9.96804711e-01]
#  [9.75335190e-01 2.46648100e-02]
#  [2.79003416e-02 9.72099658e-01]
#  [9.72840626e-01 2.71593739e-02]
#  [9.57717728e-01 4.22822718e-02]
#  [9.96764165e-01 3.23583540e-03]
#  [3.26255970e-02 9.67374403e-01]
#  [9.91543744e-01 8.45625612e-03]
#  [6.48321099e-01 3.51678901e-01]
#  [9.99581102e-01 4.18898067e-04]
#  [4.12860534e-01 5.87139466e-01]
#  [2.88332431e-02 9.71166757e-01]
#  [2.12154089e-03 9.97878459e-01]
#  [6.02847763e-02 9.39715224e-01]
#  [3.75991026e-01 6.24008974e-01]
#  [9.83390544e-04 9.99016609e-01]]

# %%
s = set()
s.add((1, 2))
s.add((0,3))
s
# Out:
# {(0, 3), (1, 2)}

# %%
import psutil

# Get the percentage of CPU usage
cpu_usage = psutil.cpu_percent()  # interval in seconds
print(f"CPU Usage: {cpu_usage}%")

# Get the per-core CPU usage
per_core_usage = sum(psutil.cpu_percent(percpu=True))/psutil.cpu_count()
print(f"Per-Core CPU Usage: {per_core_usage}")

# Get the number of physical cores and logical CPUs
physical_cores = psutil.cpu_count(logical=False)
logical_cpus = psutil.cpu_count(logical=True)
print(f"Physical Cores: {physical_cores}, Logical CPUs: {logical_cpus}")

# Get the current CPU frequency
cpu_freq = psutil.cpu_freq()
print(f"Current CPU Frequency: {cpu_freq.current} MHz")

# Get CPU load averages (1, 5, 15 minutes)
load_avg = psutil.getloadavg()
print(f"CPU Load Average (1, 5, 15 min): {load_avg}")
# Out:
# CPU Usage: 15.2%
# Per-Core CPU Usage: 15.2875
# Physical Cores: 4, Logical CPUs: 8
# Current CPU Frequency: 2100.0 MHz
# CPU Load Average (1, 5, 15 min): (0.0, 0.0, 0.0)

# %%
# x = [[0.     0.     4.     8.    ]
#  [0.     0.     4.     8.    ]
#  [4.     3.9875 4.     8.    ]
#  [2.7    2.7    4.     8.    ]
#  [5.1    5.0125 4.     8.    ]
#  [6.1    6.0125 4.     8.    ]
#  [3.6    3.625  4.     8.    ]
#  [4.5    4.5125 4.     8.    ]
#  [3.8    3.7375 4.     8.    ]
#  [2.6    2.525  4.     8.    ]]

x = np.array([[0., 0., 4., 8.],
    [0., 0., 4., 8.],
    [4., 3.9875, 4., 8.],
    [2.7, 2.7, 4., 8.],
    [5.1, 5.0125, 4., 8.],
    [6.1, 6.0125, 4., 8.],
    [3.6, 3.625, 4., 8.],
    [4.5, 4.5125, 4., 8.],
    [3.8, 3.7375, 4., 8.],
    [2.6, 2.525, 4., 8.]])
y = np.array([0, 0, 1, 1, 0, 1, 1, 0, 0, 0])

# %%
model = LogisticRegression()
model.fit(x, y)
# Out:
# LogisticRegression()

# %%
import psutil
cpu_usage = psutil.cpu_percent()
per_core_usage = sum(psutil.cpu_percent(percpu=True))/psutil.cpu_count()
physical_cores = psutil.cpu_count(logical=False)
logical_cpus = psutil.cpu_count(logical=True)
print(f"CPU Usage: {cpu_usage}, Per Core Usage: {per_core_usage}, Physical Cores: {physical_cores}, Logical CPUs: {logical_cpus}")
try:
    proba = model.predict([[cpu_usage, per_core_usage, physical_cores, logical_cpus]])
    print(proba)
except Exception as e:
    print(f"Error predicting probabilities: {e}")
    proba = 0
# Out:
# CPU Usage: 5.7, Per Core Usage: 5.5625, Physical Cores: 4, Logical CPUs: 8
# [1]

# %%
v = str(set([(12, 'a')]))

# %%
eval(v)
# Out:
# {(12, 'a')}

# %%
temp = eval(v)

# %%
temp
# Out:
# {(12, 'a')}

# %%
temp.add((12, 'a'))

# %%
temp
# Out:
# {(12, 'a')}

# %%
s = set()
s.add(3)
s.add(1)
s.add(2)

# %%
s
# Out:
# {1, 2, 3}

# %%
list(s)
# Out:
# [1, 2, 3]

# %%
parameters = {5001: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 2, 'cbm': 0}, 5002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 1}}

# %%
validators = [5001, 5002]
def score(params):
        """
        Consensus Score (CS) = [α * AIST * (1 - CST/TST) * log(1 + 1/LIT)] / [β * (CBM + 1)]
        """
        alpha = 3
        beta = 1
        aist = params['aist']
        cst = params['cst']
        tst = params['tst']
        lit = params['lit']
        cbm = params['cbm']
        
        if cst == 0:
            aist = len(validators) * 2
        if cst == 1:
            aist = len(validators)

        CS = (alpha * aist * (1 - cst/tst) * np.log(1 + 1/(lit + 0.00001))) / (beta * (cbm + 1))
        # CS = (alpha * params['aist'] * (1 - params['cst']/params['tst']) * np.log(1 + 1/params['lit'])) / (beta * (params['cbm'] + 1))
        return CS

# %%
CS = [score(parameters[val]) for val in validators]

# %%
import threading
import time
import random
import poem_global as poem
import aasc as aasc
from tabulate import tabulate

class Test:
    def __init__(self, test_type = 'throughput'):
        self.test_type = test_type

    def create_network(self, num_nodes, num_miners):
        assert num_nodes >= num_miners
        nodes = [5000 + i for i in range(num_nodes)]
        validators = random.sample(nodes, num_miners)

        edges = []
        shuffled_nodes = nodes[:]
        random.shuffle(shuffled_nodes)
        
        for i in range(1, num_nodes):
            u = shuffled_nodes[i]
            v = shuffled_nodes[random.randint(0, i - 1)]
            edges.append((u, v))
        
        possible_edges = [
            (u, v) for i, u in enumerate(nodes) for v in nodes[i + 1:]
            if (u, v) not in edges and (v, u) not in edges
        ]
        
        random.shuffle(possible_edges)
        extra_edges = random.randint(0, len(possible_edges))
        
        for _ in range(extra_edges):
            edges.append(possible_edges.pop())   

        return nodes, validators, edges
    
    def run_node(port, is_validator, address = '127.0.0.1', algo = aasc):
        node = algo.Node(address, port, is_validator)
        cli = algo.NodeCLI(node)
        
        node_thread = threading.Thread(target=node.start)
        node_thread.start()
        
        return node, cli
    
    def run_test(self, num_nodes, num_miners):
        nodes, validators, edges = self.create_network(num_nodes, num_miners)
        
        print(f"Running test for {num_nodes} nodes and {num_miners} miners")
        aasc_result = self.AASC_test(nodes, validators, edges)
        print("AASC Test Completed")
        poem_result = self.PoEM_test(nodes, validators, edges)
        print("PoEM Test Completed")

        result = {
            'AASC' : aasc_result,
            'PoEM' : poem_result
        }

        table = []
        for algo, result in result.items():
            table.append([algo, result['throughput'], result['latency']])
        
        print(f"Test Results for {num_nodes} nodes and {num_miners} miners")
        print("-" * 50)
        print(tabulate(table, headers = ['Algorithm', 'Throughput', 'Latency']))
        print("-" * 50)

        

    def AASC_test(self, nodes, validators, edges):
        active_nodes = {node : self.run_node(node, node in validators, algo = aasc) for node in nodes}
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
        
        active_nodes[nodes[0]][1].do_sval("")

        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = 1000//len(transaction_nodes)
        total_transactions = 0
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
        end_time = time.time()
        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }
        return result


    def PoEM_test(self, nodes, validators, edges):
        active_nodes = {node : self.run_node(node, node in validators, algo = poem) for node in nodes}
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
        
        active_nodes[nodes[0]][1].do_sval("")

        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = 1000//len(transaction_nodes)
        total_transactions = 0
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
        end_time = time.time()
        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }
        return result

# %%
test = Test()
test.run_test(3, 2)
# Out:
# Exception in thread Thread-85 (start):
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-86 (start):
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
# Exception in thread Thread-87 (start):
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1010, in run
#     self.run()
#   File "C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "d:\Adarsh\C++\BTP\Scratch\blockchain-python\aasc.py", line 104, in start
#     self.run()
#   File "C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1010, in run
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
#     _threading_Thread_run(self)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "d:\Adarsh\C++\BTP\Scratch\blockchain-python\aasc.py", line 104, in start
#     self._target(*self._args, **self._kwargs)
#   File "d:\Adarsh\C++\BTP\Scratch\blockchain-python\aasc.py", line 104, in start
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
# Running test for 3 nodes and 2 miners
# Error notifying peer 127.0.0.1:5002: Object of type Test is not JSON serializable
# Failed to add peer: 127.0.0.1:5002
# Error notifying peer 127.0.0.1:5002: Object of type Test is not JSON serializable
# Failed to add peer: 127.0.0.1:5002
# Messaged ID: set()
# Messaged ID: {1}
# Broadcasting message type: store_validators
#
#
# DONE
#
#
# Messaged ID: {1}
# Messaged ID: {1, 2}
# Broadcasting message type: store_validators
#
#
# DONE
#
#
# Failed to get stake from 127.0.0.1:<__main__.Test object at 0x000002265C204080>: 'Test' object cannot be interpreted as an integer
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[52], line 2
#       1 test = Test()
# ----> 2 test.run_test(3, 2)
#
# Cell In[49], line 52, in Test.run_test(self, num_nodes, num_miners)
#      49 nodes, validators, edges = self.create_network(num_nodes, num_miners)
#      51 print(f"Running test for {num_nodes} nodes and {num_miners} miners")
# ---> 52 aasc_result = self.AASC_test(nodes, validators, edges)
#      53 print("AASC Test Completed")
#      54 poem_result = self.PoEM_test(nodes, validators, edges)
#
# Cell In[49], line 88, in Test.AASC_test(self, nodes, validators, edges)
#      86         recipient = f"user{random.randint(1, 100)}"
#      87         amount = random.randint(1, 10)
# ---> 88         active_nodes[node][1].do_addtx(f"{recipient} {amount}")
#      89         total_transactions += 1
#      90 end_time = time.time()
#
# File d:\Adarsh\C++\BTP\Scratch\blockchain-python\aasc.py:390, in NodeCLI.do_addtx(self, arg)
#     388 recipient, amount = arg.split()
#     389 amount = int(amount)
# --> 390 leader = self.node.select_leader()
#     391 # self.node.blockchain.add_transaction(self.node.address, recipient, amount)
#     392 if len(self.node.messages_id) != 0:
#
# File d:\Adarsh\C++\BTP\Scratch\blockchain-python\aasc.py:82, in Node.select_leader(self)
#      80 stakes = [self.ask_stake('127.0.0.1', port) for port in self.blockchain.validators]
#      81 total_stake = sum(stakes)
# ---> 82 weights = [stake/total_stake for stake in stakes]
#      83 leader = random.choices(list(self.blockchain.validators), weights=weights)[0]
#      84 return leader
#
# ZeroDivisionError: division by zero

# %%
import threading
import time
import random
import poem_global as poem
import aasc as aasc
from tabulate import tabulate

class Test:
    def __init__(self, test_type = 'throughput', number_of_transactions = 200):
        self.test_type = test_type
        self.number_of_transactions = number_of_transactions

    def create_network(self, num_nodes, num_miners):
        assert num_nodes >= num_miners
        nodes = [6000 + i for i in range(num_nodes)]
        validators = random.sample(nodes, num_miners)

        edges = []
        shuffled_nodes = nodes[:]
        random.shuffle(shuffled_nodes)
        
        for i in range(1, num_nodes):
            u = shuffled_nodes[i]
            v = shuffled_nodes[random.randint(0, i - 1)]
            edges.append((u, v))
        
        possible_edges = [
            (u, v) for i, u in enumerate(nodes) for v in nodes[i + 1:]
            if (u, v) not in edges and (v, u) not in edges
        ]
        
        random.shuffle(possible_edges)
        extra_edges = random.randint(0, len(possible_edges))
        
        for _ in range(extra_edges):
            edges.append(possible_edges.pop())   

        print("Nodes: ", nodes)
        print("Validators: ", validators)
        print("Edges: ", edges)
        return nodes, validators, edges
    
    def run_node(self, port, is_validator, address = '127.0.0.1', algo = aasc):
        print(f"Running node on port {port}, is_validator: {is_validator}, address: {address}")
        node = algo.Node(address, port, is_validator)
        cli = algo.NodeCLI(node)
        
        node_thread = threading.Thread(target=node.start)
        node_thread.start()
        
        return node, cli
    
    def run_test(self, num_nodes, num_miners):
        nodes, validators, edges = self.create_network(num_nodes, num_miners)
        
        print(f"Running test for {num_nodes} nodes and {num_miners} miners")
        aasc_result = self.AASC_test(nodes, validators, edges)
        print("AASC Test Completed")
        # poem_result = self.PoEM_test(nodes, validators, edges)
        # print("PoEM Test Completed")
    
        # result = {
        #     'AASC' : aasc_result,
        #     'PoEM' : poem_result
        # }

        # table = []
        # for algo, result in result.items():
        #     table.append([algo, result['throughput'], result['latency']])
        
        # print(f"Test Results for {num_nodes} nodes and {num_miners} miners")
        # print("-" * 50)
        # print(tabulate(table, headers = ['Algorithm', 'Throughput', 'Latency']))
        # print("-" * 50)

        

    def AASC_test(self, nodes, validators, edges):
        print(f"AASC Nodes {nodes}")
        for node in nodes:
            print(node)
        active_nodes = {node : self.run_node(node, node in validators, algo = aasc) for node in nodes}
        print("Attempting to connect nodes")
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
            time.sleep(1)
        
        time.sleep(2)
        print("Collecting validators")
        active_nodes[nodes[0]][1].do_sval("")
        time.sleep(2)
        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = self.number_of_transactions//len(transaction_nodes)
        total_transactions = 0
        print("Starting transactions")
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
                print(f"Transaction {total_transactions} completed", end = '\r')
        end_time = time.time()
        for node in nodes:
            active_nodes[node][1].do_viewchain("")

        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }

        time.sleep(2)
        for node in nodes:
            active_nodes[node][1].do_exit("")

        return result


    def PoEM_test(self, nodes, validators, edges):
        active_nodes = {node : self.run_node(node, node in validators, algo = poem) for node in nodes}
        print("Attempting to connect nodes")
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")

        time.sleep(2)
        print("Collecting validators")
        active_nodes[nodes[0]][1].do_sval("")
        time.sleep(2)

        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = self.number_of_transactions//len(transaction_nodes)
        total_transactions = 0
        print("Starting transactions")
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
                print(f"Transaction {total_transactions} completed", end = '\r')
        end_time = time.time()
        for node in nodes:
            print(f"Viewing chain for node {node}")
            print(active_nodes[node][1].do_count(""))
        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }

        time.sleep(2)
        for node in nodes:
            active_nodes[node][1].do_exit("")

        return result

# %%
test = Test(number_of_transactions=10)
nodes, validators, edges = test.create_network(6, 4)
# Out:
# Nodes:  [6000, 6001, 6002, 6003, 6004, 6005]
# Validators:  [6003, 6005, 6002, 6004]
# Edges:  [(6005, 6001), (6003, 6005), (6002, 6003), (6000, 6005), (6004, 6005), (6001, 6004), (6000, 6001), (6000, 6004), (6003, 6004), (6001, 6003), (6002, 6004), (6000, 6002)]

# %%
active_nodes = {node : test.run_node(node, node in validators, algo = aasc) for node in nodes}
# Out:
# Running node on port 6000, is_validator: False, address: 127.0.0.1
# Running node on port 6001, is_validator: False, address: 127.0.0.1
# Running node on port 6002, is_validator: True, address: 127.0.0.1
# Running node on port 6003, is_validator: True, address: 127.0.0.1
# Running node on port 6004, is_validator: True, address: 127.0.0.1
# Running node on port 6005, is_validator: True, address: 127.0.0.1

# %%
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)

# %%
active_nodes[u][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None

# %%
active_nodes[nodes[0]][1].do_sval("")

# %%
active_nodes[nodes[0]][1].do_val("")
# Out:
# Validators: {6002, 6003, 6004, 6005}

# %%
active_nodes[nodes[0]][1].do_addtx("user1 10")
# Out:
# 6004 Blockchain length: 1
# 6004 Leader 6002
# 6003 Blockchain length: 1
# 6003 Leader 6002
# 6002 Blockchain length: 1
# 6002 Leader 6002
# 6005 Blockchain length: 1
# 6005 Leader 6002
# 6003 Blockchain length: 2
# 6003 Leader 6005
# 6005 Blockchain length: 2
# 6005 Leader 6005
# 6002 Blockchain length: 3
# 6002 Leader 6005
# 6004 Blockchain length: 3
# 6004 Leader 6005
# 6002 Blockchain length: 3
# 6002 Leader 6002
# 6004 Blockchain length: 3
# 6004 Leader 6002
# 6005 Blockchain length: 3
# 6005 Leader 6002
# 6003 Blockchain length: 4
# 6003 Leader 6002
# 6005 Blockchain length: 4
# 6005 Leader 6002
# 6002 Blockchain length: 4
# 6002 Leader 6002
# 6003 Blockchain length: 4
# 6003 Leader 6002
# 6004 Blockchain length: 5
# 6004 Leader 6002
# 6005 Blockchain length: 5
# 6005 Leader 6003
# 6002 Blockchain length: 5
# 6002 Leader 6003
# 6003 Blockchain length: 5
# 6003 Leader 6003
# 6004 Blockchain length: 5
# 6004 Leader 6003
# 6003 Blockchain length: 6
# 6003 Leader 6004
# 6005 Blockchain length: 6
# 6005 Leader 6004
# 6002 Blockchain length: 6
# 6002 Leader 6004
# 6004 Blockchain length: 6
# 6004 Leader 6004
# 6005 Blockchain length: 7
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 1}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [1.2164009062684136, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6003
# 6003 Blockchain length: 7
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 1}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6003 Consensus Scores: [1.2164009062684136, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6003 Block producer: 6003
# Block mined by 6003
# 6002 Blockchain length: 7
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 1}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [1.2164009062684136, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6003
# 6004 Blockchain length: 7
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 1}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6004 Consensus Scores: [1.2164009062684136, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6004 Block producer: 6003
# 6003 Blockchain length: 8
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 0}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 1}}
# 6003 Consensus Scores: [2.432801812536827, 331.57227739113057, 331.57227739113057, 1.1507298743474228]
# 6003 Block producer: 6003
# Block mined by 6003
# 6002 Blockchain length: 9
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 4, 'aist': 2.0, 'cst': 2, 'tst': 4, 'cbm': 2}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.22314405917157965, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6003
# 6005 Blockchain length: 9
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 4, 'aist': 2.0, 'cst': 2, 'tst': 4, 'cbm': 2}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.22314405917157965, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6003
# 6004 Blockchain length: 8
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 0}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 1}}
# 6004 Consensus Scores: [2.432801812536827, 331.57227739113057, 331.57227739113057, 1.1507298743474228]
# 6004 Block producer: 6003
# 6003 Blockchain length: 9
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 4, 'aist': 2.0, 'cst': 2, 'tst': 4, 'cbm': 1}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.33471608875736947, 331.57227739113057, 331.57227739113057, 2.3014597486948456]
# 6003 Block producer: 6003
# Block mined by 6003
# 6002 Blockchain length: 9
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 4, 'aist': 1.3333333333333333, 'cst': 3, 'tst': 4, 'cbm': 3}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.05578629372157423, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6003
# 6004 Blockchain length: 9
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 4, 'aist': 2.0, 'cst': 2, 'tst': 4, 'cbm': 1}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.33471608875736947, 331.57227739113057, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6003
# 6005 Blockchain length: 9
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 4, 'aist': 1.3333333333333333, 'cst': 3, 'tst': 4, 'cbm': 3}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.05578629372157423, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6003
# 6004 Blockchain length: 10
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 2}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.12154804694940254, 331.57227739113057, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6003
# 6005 Blockchain length: 10
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 4}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.027348447304484675, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6003
# 6002 Blockchain length: 10
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 4}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.027348447304484675, 331.57227739113057, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6003
# 6003 Blockchain length: 10
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 2}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.12154804694940254, 331.57227739113057, 331.57227739113057, 2.3014597486948456]
# 6003 Block producer: 6003
# Block mined by 6003
# 6005 Blockchain length: 11
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 6, 'aist': 6.0, 'cst': 1, 'tst': 6, 'cbm': 1}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.7707535370060229, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6004
# 6004 Blockchain length: 11
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 6, 'aist': 6.0, 'cst': 1, 'tst': 6, 'cbm': 1}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.7707535370060229, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6004
# Block mined by 6004
# 6002 Blockchain length: 11
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 6, 'aist': 6.0, 'cst': 1, 'tst': 6, 'cbm': 1}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.7707535370060229, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6004
# 6003 Blockchain length: 12
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6004: {'ss': 0, 'lit': 7, 'aist': 7.0, 'cst': 1, 'tst': 7, 'cbm': 1}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 331.57227739113057, 0.6867329480255376, 2.3014597486948456]
# 6003 Block producer: 6003
# Block mined by 6003
# 6004 Blockchain length: 13
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 8, 'aist': 4.0, 'cst': 2, 'tst': 8, 'cbm': 2}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.353349212531082, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6004
# Block mined by 6004
# 6005 Blockchain length: 13
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 8, 'aist': 4.0, 'cst': 2, 'tst': 8, 'cbm': 2}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.353349212531082, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6004
# 6002 Blockchain length: 13
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 8, 'aist': 4.0, 'cst': 2, 'tst': 8, 'cbm': 2}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.353349212531082, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6004
# 6003 Blockchain length: 14
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 9, 'aist': 9.0, 'cst': 1, 'tst': 9, 'cbm': 1}, 6004: {'ss': 0, 'lit': 7, 'aist': 7.0, 'cst': 1, 'tst': 7, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.5619227689605526, 1.3734658960510753, 2.3014597486948456]
# 6003 Block producer: 6005
# 6004 Blockchain length: 14
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 9, 'aist': 3.0, 'cst': 3, 'tst': 9, 'cbm': 3}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.15804084462039758, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6004
# Block mined by 6004
# 6005 Blockchain length: 14
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 9, 'aist': 3.0, 'cst': 3, 'tst': 9, 'cbm': 3}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.15804084462039758, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6004
# 6002 Blockchain length: 14
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 9, 'aist': 3.0, 'cst': 3, 'tst': 9, 'cbm': 3}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.15804084462039758, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6004
# 6003 Blockchain length: 15
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 10, 'aist': 5.0, 'cst': 2, 'tst': 10, 'cbm': 2}, 6004: {'ss': 0, 'lit': 7, 'aist': 7.0, 'cst': 1, 'tst': 7, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.3812407781637421, 1.3734658960510753, 2.3014597486948456]
# 6003 Block producer: 6005
# 6005 Blockchain length: 15
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 10, 'aist': 2.5, 'cst': 4, 'tst': 10, 'cbm': 4}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.08577921082812025, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6004
# 6002 Blockchain length: 15
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 10, 'aist': 2.5, 'cst': 4, 'tst': 10, 'cbm': 4}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.08577921082812025, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6004
# 6003 Blockchain length: 15
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 10, 'aist': 3.3333333333333335, 'cst': 3, 'tst': 10, 'cbm': 3}, 6004: {'ss': 0, 'lit': 7, 'aist': 7.0, 'cst': 1, 'tst': 7, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.1667928702310357, 1.3734658960510753, 2.3014597486948456]
# 6003 Block producer: 6005
# 6004 Blockchain length: 15
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 10, 'aist': 2.5, 'cst': 4, 'tst': 10, 'cbm': 4}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.08577921082812025, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6004
# Block mined by 6004
# 6005 Blockchain length: 16
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.2, 'cst': 5, 'tst': 11, 'cbm': 5}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.052206861198910215, 331.57227739113057, 331.57227739113057]
# 6005 Block producer: 6004
# 6004 Blockchain length: 16
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.2, 'cst': 5, 'tst': 11, 'cbm': 5}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.052206861198910215, 331.57227739113057, 2.3014597486948456]
# 6004 Block producer: 6004
# Block mined by 6004
# 6002 Blockchain length: 16
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.2, 'cst': 5, 'tst': 11, 'cbm': 5}, 6004: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.052206861198910215, 331.57227739113057, 331.57227739113057]
# 6002 Block producer: 6004
# 6003 Blockchain length: 16
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.75, 'cst': 4, 'tst': 11, 'cbm': 4}, 6004: {'ss': 0, 'lit': 7, 'aist': 7.0, 'cst': 1, 'tst': 7, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.09136198534527026, 1.3734658960510753, 2.3014597486948456]
# 6003 Block producer: 6005
# 6004 Blockchain length: 17
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.2, 'cst': 5, 'tst': 11, 'cbm': 0}, 6004: {'ss': 0, 'lit': 12, 'aist': 12.0, 'cst': 1, 'tst': 12, 'cbm': 1}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.3132411671934613, 0.44023489029914115, 2.3014597486948456]
# 6004 Block producer: 6005
# 6005 Blockchain length: 17
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.2, 'cst': 5, 'tst': 11, 'cbm': 0}, 6004: {'ss': 0, 'lit': 12, 'aist': 12.0, 'cst': 1, 'tst': 12, 'cbm': 1}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.3132411671934613, 0.44023489029914115, 331.57227739113057]
# 6005 Block producer: 6005
# Block mined by 6005
# 6002 Blockchain length: 17
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.2, 'cst': 5, 'tst': 11, 'cbm': 0}, 6004: {'ss': 0, 'lit': 12, 'aist': 12.0, 'cst': 1, 'tst': 12, 'cbm': 1}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.3132411671934613, 0.44023489029914115, 331.57227739113057]
# 6002 Block producer: 6005
# 6003 Blockchain length: 17
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 11, 'aist': 2.75, 'cst': 4, 'tst': 11, 'cbm': 0}, 6004: {'ss': 0, 'lit': 12, 'aist': 6.0, 'cst': 2, 'tst': 12, 'cbm': 1}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.4568099267263513, 0.6003203595278979, 2.3014597486948456]
# 6003 Block producer: 6005
# 6003 Blockchain length: 186005 Blockchain length: 18
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 1}, 6004: {'ss': 0, 'lit': 12, 'aist': 12.0, 'cst': 1, 'tst': 12, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.12968902716275596, 0.8804697805982823, 331.57227739113057]
# 6005 Block producer: 6005
# Block mined by 6005
#
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 1}, 6004: {'ss': 0, 'lit': 12, 'aist': 6.0, 'cst': 2, 'tst': 12, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.17785920549124692, 1.2006407190557957, 2.3014597486948456]
# 6003 Block producer: 6005
# 6002 Blockchain length: 18
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 1}, 6004: {'ss': 0, 'lit': 12, 'aist': 12.0, 'cst': 1, 'tst': 12, 'cbm': 0}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.12968902716275596, 0.8804697805982823, 331.57227739113057]
# 6002 Block producer: 6005
# 6004 Blockchain length: 18
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 1}, 6004: {'ss': 0, 'lit': 12, 'aist': 12.0, 'cst': 1, 'tst': 12, 'cbm': 0}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.12968902716275596, 0.8804697805982823, 2.3014597486948456]
# 6004 Block producer: 6005
# 6005 Blockchain length: 196003 Blockchain length: 19
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 14, 'aist': 4.666666666666667, 'cst': 3, 'tst': 14, 'cbm': 1}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.3794608409086349, 2.3014597486948456]
# 6003 Block producer: 6005
#
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 14, 'aist': 7.0, 'cst': 2, 'tst': 14, 'cbm': 1}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.6209358744462997, 331.57227739113057]
# 6005 Block producer: 6005
# Block mined by 6005
# 6002 Blockchain length: 19
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 14, 'aist': 7.0, 'cst': 2, 'tst': 14, 'cbm': 1}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.6209358744462997, 331.57227739113057]
# 6002 Block producer: 6005
# 6004 Blockchain length: 19
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 14, 'aist': 7.0, 'cst': 2, 'tst': 14, 'cbm': 1}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.6209358744462997, 2.3014597486948456]
# 6004 Block producer: 6005
# 6004 Blockchain length: 20
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 15, 'aist': 5.0, 'cst': 3, 'tst': 15, 'cbm': 2}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.2581541109092684, 2.3014597486948456]
# 6004 Block producer: 6005
# 6005 Blockchain length: 20
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 15, 'aist': 5.0, 'cst': 3, 'tst': 15, 'cbm': 2}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.2581541109092684, 331.57227739113057]
# 6005 Block producer: 6005
# Block mined by 6005
# 6002 Blockchain length: 20
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 15, 'aist': 5.0, 'cst': 3, 'tst': 15, 'cbm': 2}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.2581541109092684, 331.57227739113057]
# 6002 Block producer: 6005
# 6003 Blockchain length: 20
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 15, 'aist': 3.75, 'cst': 4, 'tst': 15, 'cbm': 2}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.17748096469563743, 2.3014597486948456]
# 6003 Block producer: 6005
# 6003 Blockchain length: 21
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 16, 'aist': 3.2, 'cst': 5, 'tst': 16, 'cbm': 3}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.10003064834871339, 2.3014597486948456]
# 6003 Block producer: 6005
# 6005 Blockchain length: 21
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 16, 'aist': 4.0, 'cst': 4, 'tst': 16, 'cbm': 3}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.13640541923269206, 331.57227739113057]
# 6002 Blockchain length: 21
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 16, 'aist': 4.0, 'cst': 4, 'tst': 16, 'cbm': 3}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.13640541923269206, 331.57227739113057]
# 6002 Block producer: 6005
# 6005 Block producer: 6005
# Block mined by 6005
# 6004 Blockchain length: 21
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 16, 'aist': 4.0, 'cst': 4, 'tst': 16, 'cbm': 3}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.13640541923269206, 2.3014597486948456]
# 6004 Block producer: 6005
# 6002 Blockchain length: 22
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 4}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.08230813139718868, 331.57227739113057]
# 6002 Block producer: 6005
# 6003 Blockchain length: 22
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 2.8333333333333335, 'cst': 6, 'tst': 17, 'cbm': 4}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.0628742718027172, 2.3014597486948456]
# 6003 Block producer: 6005
# 6004 Blockchain length: 22
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 4}, 6005: {'ss': 0, 'lit': 3, 'aist': 3.0, 'cst': 1, 'tst': 3, 'cbm': 0}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.08230813139718868, 2.3014597486948456]
# 6004 Block producer: 6005
# 6005 Blockchain length: 22
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 4}, 6005: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 0, 'cbm': 0}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.08230813139718868, 331.57227739113057]
# 6005 Block producer: 6005
# Block mined by 6005
# 6002 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 18.0, 'cst': 1, 'tst': 18, 'cbm': 1}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.4115406569859434, 0.3063809139748053]
# 6002 Block producer: 6004
# 6004 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 9.0, 'cst': 2, 'tst': 18, 'cbm': 1}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.4115406569859434, 0.6488066652115826]
# 6004 Block producer: 6005
# 6003 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 2.8333333333333335, 'cst': 6, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 9.0, 'cst': 2, 'tst': 18, 'cbm': 1}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.314371359013586, 0.6488066652115826]
# 6003 Block producer: 6005
# 6005 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 18.0, 'cst': 1, 'tst': 18, 'cbm': 1}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.4115406569859434, 0.3063809139748053]
# 6005 Block producer: 6004
# 6004 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 6.0, 'cst': 3, 'tst': 18, 'cbm': 2}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.4115406569859434, 0.27033612176882366]
# 6004 Block producer: 6004
# Block mined by 6004
# 6005 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 9.0, 'cst': 2, 'tst': 18, 'cbm': 2}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.4115406569859434, 0.4325377768077217]
# 6005 Block producer: 6005
# Block mined by 6005
# 6002 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 9.0, 'cst': 2, 'tst': 18, 'cbm': 2}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.4115406569859434, 0.4325377768077217]
# 6002 Block producer: 6005
# 6003 Blockchain length: 23
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 2.8333333333333335, 'cst': 6, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 18, 'aist': 6.0, 'cst': 3, 'tst': 18, 'cbm': 2}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.314371359013586, 0.27033612176882366]
# 6003 Block producer: 6002
# 6005 Blockchain length: 246003 Blockchain length: 24
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.6, 'cst': 5, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 2.8333333333333335, 'cst': 6, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 19, 'aist': 4.75, 'cst': 4, 'tst': 19, 'cbm': 3}}
# 6003 Consensus Scores: [0.3646441408482076, 0.35571841098249385, 0.314371359013586, 0.144262403311012]
# 6003 Block producer: 6002
#
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 19, 'aist': 6.333333333333333, 'cst': 3, 'tst': 19, 'cbm': 3}}
# 6005 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.4115406569859434, 0.2051731872712285]
# 6005 Block producer: 6004
# 6002 Blockchain length: 24
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.25, 'cst': 4, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 19, 'aist': 6.333333333333333, 'cst': 3, 'tst': 19, 'cbm': 3}}
# 6002 Consensus Scores: [0.13674223652242337, 0.2593780543255119, 0.4115406569859434, 0.2051731872712285]
# 6002 Block producer: 6004
# 6004 Blockchain length: 24
#
#
#
# Mining new block using AASC...
# Parameters: {6002: {'ss': 0, 'lit': 5, 'aist': 1.6666666666666667, 'cst': 3, 'tst': 5, 'cbm': 0}, 6003: {'ss': 0, 'lit': 13, 'aist': 2.1666666666666665, 'cst': 6, 'tst': 13, 'cbm': 0}, 6004: {'ss': 0, 'lit': 17, 'aist': 3.4, 'cst': 5, 'tst': 17, 'cbm': 0}, 6005: {'ss': 0, 'lit': 19, 'aist': 4.75, 'cst': 4, 'tst': 19, 'cbm': 3}}
# 6004 Consensus Scores: [0.3646441408482076, 0.2593780543255119, 0.4115406569859434, 0.144262403311012]
# 6004 Block producer: 6004
# Block mined by 6004

# %%
active_nodes[nodes[1]][1].do_addtx("user15 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733286388
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Previous Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1733286396
#   Data: ['127.0.0.16001 sends 10 coins to user2']
#   Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Previous Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733286441
#   Data: ['127.0.0.16001 sends 10 coins to user3']
#   Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Previous Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Mined by: 6002
#
# Block 4:
#   Timestamp: 1733286460
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Previous Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Mined by: 6002
#
# Block 5:
#   Timestamp: 1733286480
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Previous Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Mined by: 6003
#
# Block 6:
#   Timestamp: 1733286495
#   Data: ['127.0.0.16001 sends 10 coins to user6']
#   Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Previous Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Mined by: 6004
#
# Block 7:
#   Timestamp: 1733286517
#   Data: ['127.0.0.16001 sends 10 coins to user7']
#   Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Previous Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733286536
#   Data: ['127.0.0.16001 sends 10 coins to user8']
#   Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Previous Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733286585
#   Data: ['127.0.0.16001 sends 10 coins to user9']
#   Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Previous Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733286678
#   Data: ['127.0.0.16001 sends 10 coins to user10']
#   Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Previous Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Mined by: 6003
#
# Block 11:
#   Timestamp: 1733286691
#   Data: ['127.0.0.16001 sends 10 coins to user11']
#   Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Previous Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733286691
#   Data: []
#   Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Previous Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Mined by: 6003
#
# Block 13:
#   Timestamp: 1733286725
#   Data: ['127.0.0.16001 sends 10 coins to user12']
#   Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Previous Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Mined by: 6004
#
# Block 14:
#   Timestamp: 1733286738
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Previous Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Mined by: 6004
#
# Block 15:
#   Timestamp: 1733286750
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Previous Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Mined by: 6004
#
# Block 16:
#   Timestamp: 1733286762
#   Data: ['127.0.0.16001 sends 10 coins to user14']
#   Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Previous Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Mined by: 6004
#
# Block 17:
#   Timestamp: 1733286775
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Previous Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Mined by: 6005
#
# Block 18:
#   Timestamp: 1733286792
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Previous Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Mined by: 6005
#
# Block 19:
#   Timestamp: 1733286802
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Previous Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Mined by: 6005
#
# Block 20:
#   Timestamp: 1733286809
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Previous Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Mined by: 6005
#
# Block 21:
#   Timestamp: 1733286816
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Previous Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Mined by: 6005
#
# Block 22:
#   Timestamp: 1733286821
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Previous Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Mined by: 6005
#
# Block 23:
#   Timestamp: 1733286833
#   Data: ['127.0.0.16001 sends 10 coins to user15', '127.0.0.16001 sends 10 coins to user15']
#   Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Previous Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Mined by: 6004
#
# Block 24:
#   Timestamp: 1733286838
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: ad5ec28d4509ddf0fd2d33a4678915dd7354ee0783a6da91f5abffbe98da7590
#   Previous Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Mined by: 6004
#
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733286388
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Previous Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1733286396
#   Data: ['127.0.0.16001 sends 10 coins to user2']
#   Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Previous Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733286441
#   Data: ['127.0.0.16001 sends 10 coins to user3']
#   Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Previous Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Mined by: 6002
#
# Block 4:
#   Timestamp: 1733286460
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Previous Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Mined by: 6002
#
# Block 5:
#   Timestamp: 1733286480
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Previous Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Mined by: 6003
#
# Block 6:
#   Timestamp: 1733286495
#   Data: ['127.0.0.16001 sends 10 coins to user6']
#   Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Previous Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Mined by: 6004
#
# Block 7:
#   Timestamp: 1733286517
#   Data: ['127.0.0.16001 sends 10 coins to user7']
#   Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Previous Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733286536
#   Data: ['127.0.0.16001 sends 10 coins to user8']
#   Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Previous Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733286585
#   Data: ['127.0.0.16001 sends 10 coins to user9']
#   Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Previous Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733286678
#   Data: ['127.0.0.16001 sends 10 coins to user10']
#   Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Previous Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Mined by: 6003
#
# Block 11:
#   Timestamp: 1733286691
#   Data: ['127.0.0.16001 sends 10 coins to user11']
#   Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Previous Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733286691
#   Data: []
#   Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Previous Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Mined by: 6003
#
# Block 13:
#   Timestamp: 1733286725
#   Data: ['127.0.0.16001 sends 10 coins to user12']
#   Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Previous Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Mined by: 6004
#
# Block 14:
#   Timestamp: 1733286738
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Previous Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Mined by: 6004
#
# Block 15:
#   Timestamp: 1733286750
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Previous Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Mined by: 6004
#
# Block 16:
#   Timestamp: 1733286762
#   Data: ['127.0.0.16001 sends 10 coins to user14']
#   Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Previous Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Mined by: 6004
#
# Block 17:
#   Timestamp: 1733286775
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Previous Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Mined by: 6005
#
# Block 18:
#   Timestamp: 1733286792
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Previous Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Mined by: 6005
#
# Block 19:
#   Timestamp: 1733286802
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Previous Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Mined by: 6005
#
# Block 20:
#   Timestamp: 1733286809
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Previous Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Mined by: 6005
#
# Block 21:
#   Timestamp: 1733286816
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Previous Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Mined by: 6005
#
# Block 22:
#   Timestamp: 1733286821
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Previous Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Mined by: 6005
#
# Block 23:
#   Timestamp: 1733286833
#   Data: ['127.0.0.16001 sends 10 coins to user15', '127.0.0.16001 sends 10 coins to user15']
#   Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Previous Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Mined by: 6005
#
# Block 24:
#   Timestamp: 1733286838
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: ad5ec28d4509ddf0fd2d33a4678915dd7354ee0783a6da91f5abffbe98da7590
#   Previous Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Mined by: 6004
#
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733286388
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Previous Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1733286396
#   Data: ['127.0.0.16001 sends 10 coins to user2']
#   Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Previous Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733286441
#   Data: ['127.0.0.16001 sends 10 coins to user3']
#   Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Previous Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Mined by: 6002
#
# Block 4:
#   Timestamp: 1733286460
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Previous Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Mined by: 6002
#
# Block 5:
#   Timestamp: 1733286480
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Previous Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Mined by: 6003
#
# Block 6:
#   Timestamp: 1733286495
#   Data: ['127.0.0.16001 sends 10 coins to user6']
#   Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Previous Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Mined by: 6004
#
# Block 7:
#   Timestamp: 1733286517
#   Data: ['127.0.0.16001 sends 10 coins to user7']
#   Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Previous Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733286536
#   Data: ['127.0.0.16001 sends 10 coins to user8']
#   Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Previous Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733286585
#   Data: ['127.0.0.16001 sends 10 coins to user9']
#   Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Previous Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733286678
#   Data: ['127.0.0.16001 sends 10 coins to user10']
#   Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Previous Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Mined by: 6003
#
# Block 11:
#   Timestamp: 1733286691
#   Data: ['127.0.0.16001 sends 10 coins to user11']
#   Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Previous Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733286691
#   Data: []
#   Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Previous Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Mined by: 6003
#
# Block 13:
#   Timestamp: 1733286725
#   Data: ['127.0.0.16001 sends 10 coins to user12']
#   Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Previous Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Mined by: 6004
#
# Block 14:
#   Timestamp: 1733286738
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Previous Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Mined by: 6004
#
# Block 15:
#   Timestamp: 1733286750
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Previous Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Mined by: 6004
#
# Block 16:
#   Timestamp: 1733286762
#   Data: ['127.0.0.16001 sends 10 coins to user14']
#   Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Previous Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Mined by: 6004
#
# Block 17:
#   Timestamp: 1733286775
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Previous Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Mined by: 6005
#
# Block 18:
#   Timestamp: 1733286792
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Previous Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Mined by: 6005
#
# Block 19:
#   Timestamp: 1733286802
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Previous Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Mined by: 6005
#
# Block 20:
#   Timestamp: 1733286809
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Previous Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Mined by: 6005
#
# Block 21:
#   Timestamp: 1733286816
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Previous Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Mined by: 6005
#
# Block 22:
#   Timestamp: 1733286821
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Previous Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Mined by: 6005
#
# Block 23:
#   Timestamp: 1733286833
#   Data: ['127.0.0.16001 sends 10 coins to user15', '127.0.0.16001 sends 10 coins to user15']
#   Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Previous Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Mined by: 6004
#
# Block 24:
#   Timestamp: 1733286838
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: ad5ec28d4509ddf0fd2d33a4678915dd7354ee0783a6da91f5abffbe98da7590
#   Previous Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Mined by: 6004
#
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733286388
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Previous Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1733286396
#   Data: ['127.0.0.16001 sends 10 coins to user2']
#   Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Previous Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733286441
#   Data: ['127.0.0.16001 sends 10 coins to user3']
#   Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Previous Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Mined by: 6002
#
# Block 4:
#   Timestamp: 1733286460
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Previous Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Mined by: 6002
#
# Block 5:
#   Timestamp: 1733286480
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Previous Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Mined by: 6003
#
# Block 6:
#   Timestamp: 1733286495
#   Data: ['127.0.0.16001 sends 10 coins to user6']
#   Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Previous Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Mined by: 6004
#
# Block 7:
#   Timestamp: 1733286517
#   Data: ['127.0.0.16001 sends 10 coins to user7']
#   Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Previous Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733286536
#   Data: ['127.0.0.16001 sends 10 coins to user8']
#   Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Previous Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733286585
#   Data: ['127.0.0.16001 sends 10 coins to user9']
#   Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Previous Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733286678
#   Data: ['127.0.0.16001 sends 10 coins to user10']
#   Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Previous Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Mined by: 6003
#
# Block 11:
#   Timestamp: 1733286691
#   Data: ['127.0.0.16001 sends 10 coins to user11']
#   Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Previous Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733286691
#   Data: []
#   Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Previous Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Mined by: 6003
#
# Block 13:
#   Timestamp: 1733286725
#   Data: ['127.0.0.16001 sends 10 coins to user12']
#   Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Previous Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Mined by: 6004
#
# Block 14:
#   Timestamp: 1733286738
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Previous Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Mined by: 6004
#
# Block 15:
#   Timestamp: 1733286750
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Previous Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Mined by: 6004
#
# Block 16:
#   Timestamp: 1733286762
#   Data: ['127.0.0.16001 sends 10 coins to user14']
#   Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Previous Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Mined by: 6004
#
# Block 17:
#   Timestamp: 1733286775
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Previous Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Mined by: 6005
#
# Block 18:
#   Timestamp: 1733286792
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Previous Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Mined by: 6005
#
# Block 19:
#   Timestamp: 1733286802
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Previous Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Mined by: 6005
#
# Block 20:
#   Timestamp: 1733286809
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Previous Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Mined by: 6005
#
# Block 21:
#   Timestamp: 1733286816
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Previous Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Mined by: 6005
#
# Block 22:
#   Timestamp: 1733286821
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Previous Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Mined by: 6005
#
# Block 23:
#   Timestamp: 1733286833
#   Data: ['127.0.0.16001 sends 10 coins to user15', '127.0.0.16001 sends 10 coins to user15']
#   Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Previous Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Mined by: 6005
#
# Block 24:
#   Timestamp: 1733286838
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: ad5ec28d4509ddf0fd2d33a4678915dd7354ee0783a6da91f5abffbe98da7590
#   Previous Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Mined by: 6004
#
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733286388
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Previous Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1733286396
#   Data: ['127.0.0.16001 sends 10 coins to user2']
#   Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Previous Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733286441
#   Data: ['127.0.0.16001 sends 10 coins to user3']
#   Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Previous Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Mined by: 6002
#
# Block 4:
#   Timestamp: 1733286460
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Previous Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Mined by: 6002
#
# Block 5:
#   Timestamp: 1733286480
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Previous Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Mined by: 6003
#
# Block 6:
#   Timestamp: 1733286495
#   Data: ['127.0.0.16001 sends 10 coins to user6']
#   Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Previous Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Mined by: 6004
#
# Block 7:
#   Timestamp: 1733286517
#   Data: ['127.0.0.16001 sends 10 coins to user7']
#   Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Previous Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733286536
#   Data: ['127.0.0.16001 sends 10 coins to user8']
#   Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Previous Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733286585
#   Data: ['127.0.0.16001 sends 10 coins to user9']
#   Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Previous Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733286678
#   Data: ['127.0.0.16001 sends 10 coins to user10']
#   Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Previous Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Mined by: 6003
#
# Block 11:
#   Timestamp: 1733286691
#   Data: ['127.0.0.16001 sends 10 coins to user11']
#   Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Previous Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733286691
#   Data: []
#   Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Previous Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Mined by: 6003
#
# Block 13:
#   Timestamp: 1733286725
#   Data: ['127.0.0.16001 sends 10 coins to user12']
#   Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Previous Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Mined by: 6004
#
# Block 14:
#   Timestamp: 1733286738
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Previous Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Mined by: 6004
#
# Block 15:
#   Timestamp: 1733286750
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Previous Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Mined by: 6004
#
# Block 16:
#   Timestamp: 1733286762
#   Data: ['127.0.0.16001 sends 10 coins to user14']
#   Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Previous Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Mined by: 6004
#
# Block 17:
#   Timestamp: 1733286775
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Previous Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Mined by: 6005
#
# Block 18:
#   Timestamp: 1733286792
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Previous Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Mined by: 6005
#
# Block 19:
#   Timestamp: 1733286802
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Previous Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Mined by: 6005
#
# Block 20:
#   Timestamp: 1733286809
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Previous Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Mined by: 6005
#
# Block 21:
#   Timestamp: 1733286816
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Previous Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Mined by: 6005
#
# Block 22:
#   Timestamp: 1733286821
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Previous Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Mined by: 6005
#
# Block 23:
#   Timestamp: 1733286833
#   Data: ['127.0.0.16001 sends 10 coins to user15', '127.0.0.16001 sends 10 coins to user15']
#   Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Previous Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Mined by: 6004
#
# Block 24:
#   Timestamp: 1733286838
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: ad5ec28d4509ddf0fd2d33a4678915dd7354ee0783a6da91f5abffbe98da7590
#   Previous Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Mined by: 6004
#
# Block 0:
#   Timestamp: 1733286347
#   Data: Genesis Block
#   Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733286388
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Previous Hash: a410fa10b8044fd6436ee230ed5b2fa0e5f79640cf9d6d001b568241a38da819
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1733286396
#   Data: ['127.0.0.16001 sends 10 coins to user2']
#   Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Previous Hash: f0034988f124b66af4ac74aa17e4693da568cc65665bb2ebf6c588d89478736c
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733286441
#   Data: ['127.0.0.16001 sends 10 coins to user3']
#   Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Previous Hash: 14545748af74833dcee5ca738a2fb2476aac35c784b3f220cc06507736860a67
#   Mined by: 6002
#
# Block 4:
#   Timestamp: 1733286460
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Previous Hash: b18e75b000294f49118397491c3a7ba5e35d9ca7f52633f3f8e73304f5811b0c
#   Mined by: 6002
#
# Block 5:
#   Timestamp: 1733286480
#   Data: ['127.0.0.16001 sends 10 coins to user4']
#   Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Previous Hash: bc2052570c568dd9fda6f9db000e28e54db97bf6555ee4ea3b306fc4de79e71e
#   Mined by: 6003
#
# Block 6:
#   Timestamp: 1733286495
#   Data: ['127.0.0.16001 sends 10 coins to user6']
#   Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Previous Hash: fd462c4b7c8c6956c4ff1488b205588645ceca5ec854d597af923744031058e7
#   Mined by: 6004
#
# Block 7:
#   Timestamp: 1733286517
#   Data: ['127.0.0.16001 sends 10 coins to user7']
#   Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Previous Hash: b59ad1a3b9babdc7225b5b0f821e0e04ba09444f345b4106f7310fcb5b7bad3d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733286536
#   Data: ['127.0.0.16001 sends 10 coins to user8']
#   Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Previous Hash: fe11e463ebb2b4096082918482f8af19449435903cceec60e2ece56c899fa430
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733286585
#   Data: ['127.0.0.16001 sends 10 coins to user9']
#   Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Previous Hash: a9353c46f6955c77ec7edb9e2164418775061d6d528b960401be7da19236b706
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733286678
#   Data: ['127.0.0.16001 sends 10 coins to user10']
#   Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Previous Hash: 8186ac698d049992098a603150df8eec0fb8deb57011e1f32bce041ec6ea3c28
#   Mined by: 6003
#
# Block 11:
#   Timestamp: 1733286691
#   Data: ['127.0.0.16001 sends 10 coins to user11']
#   Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Previous Hash: 5d4984363562559a1c128ca408bda180cc86c873a15b82bc98a176c3db57681c
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733286691
#   Data: []
#   Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Previous Hash: 76919350b96dcef042e806b2214cfa3b57821b89e73ed8ea73f462397af3fd69
#   Mined by: 6003
#
# Block 13:
#   Timestamp: 1733286725
#   Data: ['127.0.0.16001 sends 10 coins to user12']
#   Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Previous Hash: 84345e1da4d33fb5e862a2980e958a79973bcfdd8c914481f304bb9c1d094143
#   Mined by: 6004
#
# Block 14:
#   Timestamp: 1733286738
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Previous Hash: 42554a15ba1f934a1eba8bb2c990495fc6526fe1044fafb9c8fe8cd4fccf9345
#   Mined by: 6004
#
# Block 15:
#   Timestamp: 1733286750
#   Data: ['127.0.0.16001 sends 10 coins to user13']
#   Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Previous Hash: 34c7097a4661761c30dd25878c6bdb59bdd60ef2afac4ca9d4e16950382005e8
#   Mined by: 6004
#
# Block 16:
#   Timestamp: 1733286762
#   Data: ['127.0.0.16001 sends 10 coins to user14']
#   Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Previous Hash: df140f54b6d0bf8bb5e40bc7516588532c276c549d9009287414c3511125f19c
#   Mined by: 6004
#
# Block 17:
#   Timestamp: 1733286775
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Previous Hash: e02e0cbdd7ecbdbcdde262ad8794eaaedb39f05afdd35ecac46887867d0388b9
#   Mined by: 6005
#
# Block 18:
#   Timestamp: 1733286792
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Previous Hash: bedb88e84b0a7043f71c200ec77d7345bc539725d4322bf9acd317cbd5d9a036
#   Mined by: 6005
#
# Block 19:
#   Timestamp: 1733286802
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Previous Hash: 3f5d1e24d67a95a532d4aeb6c4eae71b5ef23968fad6fa1f50c0618aaa04196e
#   Mined by: 6005
#
# Block 20:
#   Timestamp: 1733286809
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Previous Hash: be823ebb887b6de711c2cd801aa3871f3a1d914e314f63bec8510054f0f08b83
#   Mined by: 6005
#
# Block 21:
#   Timestamp: 1733286816
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Previous Hash: e1686ea7ea3473812a6c25cefeb8cac372a23ab37ab999f3da28a3be59cbf7f7
#   Mined by: 6005
#
# Block 22:
#   Timestamp: 1733286821
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Previous Hash: 60b87e3663c244e74851d74f0948d6658cbf06dfaa3a9e245982ffbf58535367
#   Mined by: 6005
#
# Block 23:
#   Timestamp: 1733286833
#   Data: ['127.0.0.16001 sends 10 coins to user15', '127.0.0.16001 sends 10 coins to user15']
#   Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Previous Hash: c4c37b5366aa0262c2d60268cff064f5cf895a24276176d3fbbec2d5f479ccf8
#   Mined by: 6005
#
# Block 24:
#   Timestamp: 1733286838
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: ad5ec28d4509ddf0fd2d33a4678915dd7354ee0783a6da91f5abffbe98da7590
#   Previous Hash: c241b8e724fdaf3775ee6fe3aef175f8d774c669936fe69b67563c3452a61c33
#   Mined by: 6004

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005
#
# Block 0:
#   Timestamp: 1733285232
#   Data: Genesis Block
#   Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733285259
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Previous Hash: 507cc7bf9d1bbbe78e378a958eee13f45d5cc3a64faace230b51f4c3804461e7
#   Mined by: 6003
#
# Block 2:
#   Timestamp: 1733285262
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Previous Hash: 4815e2b8c1ecd6b22fe103e0845a47e1a4b4089380f5e150875a9e623c830886
#   Mined by: 6005
#
# Block 3:
#   Timestamp: 1733285266
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Previous Hash: 76507e5e226a6256e1d962fccb4f60b7729bcd3bf332041e0d7951f6ad130e15
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733285281
#   Data: ['127.0.0.16001 sends 10 coins to user1', '127.0.0.16001 sends 10 coins to user1']
#   Hash: 8b5d67d4fa6770a430a5ccc788713b144816bb6eeef0010245b4b7ae9026be99
#   Previous Hash: 819680dda49f8919f15dcde83bd2fdf6a111a44bd574692ed22874dbb6e456fa
#   Mined by: 6005

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733284320
#   Data: Genesis Block
#   Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733284340
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Previous Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Mined by: 6004
#
# Block 2:
#   Timestamp: 1733284348
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Previous Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Mined by: 6000
#
# Block 3:
#   Timestamp: 1733284432
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Previous Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733284435
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Previous Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733284494
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Previous Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Mined by: 6005
#
# Block 6:
#   Timestamp: 1733284514
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: a1f2b3a1b12ce9a48235f579331354899dcd4d0b3d45e2cc934620d66e73d97c
#   Previous Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1733284320
#   Data: Genesis Block
#   Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733284340
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Previous Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Mined by: 6004
#
# Block 2:
#   Timestamp: 1733284348
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Previous Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Mined by: 6000
#
# Block 3:
#   Timestamp: 1733284432
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Previous Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733284435
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Previous Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733284494
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Previous Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Mined by: 6005
#
# Block 6:
#   Timestamp: 1733284514
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: a1f2b3a1b12ce9a48235f579331354899dcd4d0b3d45e2cc934620d66e73d97c
#   Previous Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1733284320
#   Data: Genesis Block
#   Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733284340
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Previous Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Mined by: 6004
#
# Block 2:
#   Timestamp: 1733284348
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Previous Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Mined by: 6000
#
# Block 3:
#   Timestamp: 1733284432
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Previous Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733284435
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Previous Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733284494
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Previous Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Mined by: 6005
#
# Block 6:
#   Timestamp: 1733284514
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: a1f2b3a1b12ce9a48235f579331354899dcd4d0b3d45e2cc934620d66e73d97c
#   Previous Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1733284320
#   Data: Genesis Block
#   Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733284340
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Previous Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Mined by: 6004
#
# Block 2:
#   Timestamp: 1733284348
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Previous Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Mined by: 6000
#
# Block 3:
#   Timestamp: 1733284432
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Previous Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733284435
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Previous Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733284494
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Previous Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Mined by: 6005
#
# Block 6:
#   Timestamp: 1733284514
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: a1f2b3a1b12ce9a48235f579331354899dcd4d0b3d45e2cc934620d66e73d97c
#   Previous Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1733284320
#   Data: Genesis Block
#   Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733284340
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Previous Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Mined by: 6004
#
# Block 2:
#   Timestamp: 1733284348
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Previous Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Mined by: 6000
#
# Block 3:
#   Timestamp: 1733284432
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Previous Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733284435
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Previous Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733284494
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Previous Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Mined by: 6005
#
# Block 6:
#   Timestamp: 1733284514
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: a1f2b3a1b12ce9a48235f579331354899dcd4d0b3d45e2cc934620d66e73d97c
#   Previous Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1733284320
#   Data: Genesis Block
#   Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733284340
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Previous Hash: b090d4b5514d18d5937d1c9463a5fb69c8e9bcb9ab491cfeded5e6a8d5a3be30
#   Mined by: 6004
#
# Block 2:
#   Timestamp: 1733284348
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Previous Hash: 0164b0a5233fb291145e2f73fe708a725542f9321372d71a6c26978d14fcb2c5
#   Mined by: 6000
#
# Block 3:
#   Timestamp: 1733284432
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Previous Hash: e7e905367af9e98c2411e9aaf26b3438d4550ff48c5323319b05f51a05cf9481
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733284435
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Previous Hash: f1c56007190d5ea06ee9af61a6e6c0c1313e8517713a586ee29a38599ddb778c
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733284494
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Previous Hash: 3eb2f8a14ce2ddea20eafb746f62132c529220c973d2e31b5bc58f5cb6084744
#   Mined by: 6005
#
# Block 6:
#   Timestamp: 1733284514
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: a1f2b3a1b12ce9a48235f579331354899dcd4d0b3d45e2cc934620d66e73d97c
#   Previous Hash: cba7e7451efaf59693afbb0248d14dd63136906a2bf84e591a39f2b27651bad5
#   Mined by: 6003

# %%
a = {1: 2, 3: 4}
b = {3: 6, 7: 8}
a.update(b)
a
# Out:
# {1: 2, 3: 6, 7: 8}

# %%
import pos as pos
import threading
import time
def run_node(port, is_validator, address = '127.0.0.1', algo = pos):
    print(f"Running node on port {port}, is_validator: {is_validator}, address: {address}")
    node = algo.Node(address, port, is_validator)
    cli = algo.NodeCLI(node)
    
    node_thread = threading.Thread(target=node.start)
    node_thread.start()
    
    return node, cli

nodes = [6000 + i for i in range(6)]
validators = [6002, 6003, 6004, 6005]
edges = [(6000, 6002), (6000, 6003), (6000, 6004), (6000, 6005), (6001, 6002)]

active_nodes = {node : run_node(node, node in validators, algo = pos) for node in nodes}
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)
# Out:
# Running node on port 6000, is_validator: False, address: 127.0.0.1
# Running node on port 6001, is_validator: False, address: 127.0.0.1
# Running node on port 6002, is_validator: True, address: 127.0.0.1
# Running node on port 6003, is_validator: True, address: 127.0.0.1
# Running node on port 6004, is_validator: True, address: 127.0.0.1
# Running node on port 6005, is_validator: True, address: 127.0.0.1
# Added peer: 127.0.0.1:6000
# Successfully notified peer 127.0.0.1:6002 to add us as a peer.
# Peer added: 127.0.0.1:6002
# Added peer: 127.0.0.1:6000
# Successfully notified peer 127.0.0.1:6003 to add us as a peer.
# Peer added: 127.0.0.1:6003
# Added peer: 127.0.0.1:6000
# Successfully notified peer 127.0.0.1:6004 to add us as a peer.
# Peer added: 127.0.0.1:6004
# Added peer: 127.0.0.1:6000
# Successfully notified peer 127.0.0.1:6005 to add us as a peer.
# Peer added: 127.0.0.1:6005
# Added peer: 127.0.0.1:6001
# Successfully notified peer 127.0.0.1:6002 to add us as a peer.
# Peer added: 127.0.0.1:6002

# %%
active_nodes[6000][1].do_sval("")
# Out:
# 6000 -> Messaged ID: set()
# 6000 -> Messaged ID: {1}
# 6000 -> Broadcasting message type: store_validators
# 6000 -> Messaged ID: {1}
# 6000 -> Messaged ID: {1, 2}
# 6000 -> Broadcasting message type: store_validators
# 6005 -> Messaged ID: set()
# 6005 -> Messaged ID: {1}
# 6005 -> Broadcasting message type: store_validators
# 6004 -> Messaged ID: set()
# 6004 -> Messaged ID: {1}
# 6004 -> Broadcasting message type: store_validators
# 6002 -> Messaged ID: set()
# 6002 -> Messaged ID: {1}
# 6002 -> Broadcasting message type: store_validators
# 6003 -> Messaged ID: set()
# 6003 -> Messaged ID: {1}
# 6003 -> Broadcasting message type: store_validators
# 6001 -> Messaged ID: set()
# 6001 -> Messaged ID: {1}
# 6001 -> Broadcasting message type: store_validators
# 6004 -> Messaged ID: {1}
# 6004 -> Messaged ID: {1, 2}
# 6004 -> Broadcasting message type: store_validators
# 6005 -> Messaged ID: {1}
# 6005 -> Messaged ID: {1, 2}
# 6005 -> Broadcasting message type: store_validators
# 6002 -> Messaged ID: {1}
# 6002 -> Messaged ID: {1, 2}
# 6002 -> Broadcasting message type: store_validators
# 6003 -> Messaged ID: {1}
# 6003 -> Messaged ID: {1, 2}
# 6003 -> Broadcasting message type: store_validators
# 6001 -> Messaged ID: {1}
# 6001 -> Messaged ID: {1, 2}
# 6001 -> Broadcasting message type: store_validators

# %%
active_nodes[6001][1].do_val("")
# Out:
# Validators: {6002, 6003, 6004, 6005}

# %%
active_nodes[6000][1].do_addtx("user1 10")
# Out:
# 6000 -> Messaged ID: set()
# 6000 -> Messaged ID: {1}
# 6000 -> Broadcasting message type: get_vstakes
# Stakes Response from peer ('127.0.0.1', 6004): {'stakes': {'6004': 46}}
# Updated stakes: {'6004': 46}
# Stakes Response from peer ('127.0.0.1', 6003): {'stakes': {'6003': 20, '6004': 46}}
# Updated stakes: {'6004': 46, '6003': 20}
# Stakes Response from peer ('127.0.0.1', 6005): {'stakes': {'6005': 34, '6004': 46, '6003': 20}}
# Updated stakes: {'6004': 46, '6003': 20, '6005': 34}
# Stakes Response from peer ('127.0.0.1', 6002): {'stakes': {'6002': 36, '6004': 46, '6003': 20}}
# Updated stakes: {'6004': 46, '6003': 20, '6005': 34, '6002': 36}
# 6000 -> Messaged ID: {1}
# 6000 -> Messaged ID: {1, 2}
# 6000 -> Broadcasting message type: get_vstakes
# Stakes Response from peer ('127.0.0.1', 6003): {'stakes': {'6003': 20, '6004': 46, '6005': 34, '6002': 36}}
# Updated stakes: {'6004': 46, '6003': 20, '6005': 34, '6002': 36}
# Stakes Response from peer ('127.0.0.1', 6004): {'stakes': {'6004': 46, '6003': 20, '6005': 34, '6002': 36}}
# Updated stakes: {'6004': 46, '6003': 20, '6005': 34, '6002': 36}
# Stakes Response from peer ('127.0.0.1', 6002): {'stakes': {'6002': 36, '6004': 46, '6003': 20, '6005': 34}}
# Updated stakes: {'6004': 46, '6003': 20, '6005': 34, '6002': 36}
# Stakes Response from peer ('127.0.0.1', 6005): {'stakes': {'6005': 34, '6004': 46, '6003': 20, '6002': 36}}
# Updated stakes: {'6004': 46, '6003': 20, '6005': 34, '6002': 36}
# FINAL STAKES:  {'6004': 46, '6003': 20, '6005': 34, '6002': 36}
# LEADER:  6003
# Brodcasting from 6000
# 6000 -> Messaged ID: {1, 2}
# 6000 -> Messaged ID: {1, 2, 3}
# 6000 -> Broadcasting message type: new_transaction
# Transaction added: 127.0.0.16000 sends 10 coins to user1
# Updated stakes: {6004: 46}
# 6004 -> Messaged ID: set()
# 6004 -> Messaged ID: {1}
# 6004 -> Broadcasting message type: get_vstakes
# Updated stakes: {6003: 20}
# 6003 -> Messaged ID: set()
# 6003 -> Messaged ID: {1}
# 6003 -> Broadcasting message type: get_vstakes
# Updated stakes: {6002: 36}
# 6002 -> Messaged ID: set()
# 6002 -> Messaged ID: {1}
# 6002 -> Broadcasting message type: get_vstakes
# Updated stakes: {6005: 34}
# 6005 -> Messaged ID: set()
# 6005 -> Messaged ID: {1}
# 6005 -> Broadcasting message type: get_vstakes
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {}}
# Updated stakes: {6004: 46}
# Updated stakes: {'6002': 36}
# 6001 -> Messaged ID: set()
# 6001 -> Messaged ID: {1}
# 6001 -> Broadcasting message type: get_vstakes
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46}}
# Updated stakes: {6003: 20, '6004': 46}
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46, '6003': 20}}
# Updated stakes: {6002: 36, '6004': 46, '6003': 20}
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46, '6003': 20}}
# Updated stakes: {6005: 34, '6004': 46, '6003': 20}
# Stakes Response from peer ('127.0.0.1', 6002): {'stakes': {'6002': 36, '6004': 46, '6003': 20}}
# Updated stakes: {'6002': 36, '6004': 46, '6003': 20}
# Stakes Response from peer ('127.0.0.1', 6001): {'stakes': {'6002': 36, '6004': 46, '6003': 20}}
# Updated stakes: {6002: 36, '6004': 46, '6003': 20, '6002': 36}
# Updated stakes: {6002: 36, '6004': 46, '6003': 20, '6002': 36, '6005': 34}
# 6002 -> Messaged ID: {1}
# 6002 -> Messaged ID: {1, 2}
# 6002 -> Broadcasting message type: get_vstakes
# Updated stakes: {6003: 20, '6004': 46, '6003': 20, '6005': 34, '6002': 36}
# 6003 -> Messaged ID: {1}
# 6003 -> Messaged ID: {1, 2}
# 6003 -> Broadcasting message type: get_vstakes
# Updated stakes: {'6002': 36, '6004': 46, '6003': 20, '6005': 34}
# 6001 -> Messaged ID: {1}
# 6001 -> Messaged ID: {1, 2}
# 6001 -> Broadcasting message type: get_vstakes
# Updated stakes: {6004: 46, '6004': 46, '6003': 20, '6005': 34, '6002': 36}
# 6004 -> Messaged ID: {1}
# 6004 -> Messaged ID: {1, 2}
# 6004 -> Broadcasting message type: get_vstakes
# Updated stakes: {6005: 34, '6004': 46, '6003': 20, '6005': 34, '6002': 36}
# 6005 -> Messaged ID: {1}
# 6005 -> Messaged ID: {1, 2}
# 6005 -> Broadcasting message type: get_vstakes
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46, '6003': 20, '6005': 34, '6002': 36}}
# Updated stakes: {6002: 36, '6004': 46, '6003': 20, '6002': 36, '6005': 34}
# Stakes Response from peer ('127.0.0.1', 6002): {'stakes': {'6002': 36, '6004': 46, '6003': 20, '6005': 34}}
# Updated stakes: {'6002': 36, '6004': 46, '6003': 20, '6005': 34}
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46, '6003': 20, '6005': 34, '6002': 36}}
# Updated stakes: {6003: 20, '6004': 46, '6003': 20, '6005': 34, '6002': 36}
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46, '6003': 20, '6005': 34, '6002': 36}}
# Updated stakes: {6004: 46, '6004': 46, '6003': 20, '6005': 34, '6002': 36}
# Stakes Response from peer ('127.0.0.1', 6001): {'stakes': {'6002': 36, '6004': 46, '6003': 20, '6005': 34}}
# Updated stakes: {6002: 36, '6004': 46, '6003': 20, '6002': 36, '6005': 34}
# Stakes Response from peer ('127.0.0.1', 6000): {'stakes': {'6004': 46, '6003': 20, '6005': 34, '6002': 36}}
# Updated stakes: {6005: 34, '6004': 46, '6003': 20, '6005': 34, '6002': 36}
# 6002 -> Received new transaction
# 6002 -> Messaged ID: {1, 2}
# 6002 -> Messaged ID: {1, 2, 3}
# 6002 -> Broadcasting message type: new_transaction
# 6003 -> Received new transaction
# 6003 -> Messaged ID: {1, 2}
# 6003 -> Messaged ID: {1, 2, 3}
# 6003 -> Broadcasting message type: new_transaction
# 6005 -> Received new transaction
# 6005 -> Messaged ID: {1, 2}
# 6005 -> Messaged ID: {1, 2, 3}
# 6005 -> Broadcasting message type: new_transaction
# 6004 -> Received new transaction
# 6004 -> Messaged ID: {1, 2}
# 6004 -> Messaged ID: {1, 2, 3}
# 6004 -> Broadcasting message type: new_transaction
# 6001 -> Received new transaction
# 6001 -> Messaged ID: {1, 2}
# 6001 -> Messaged ID: {1, 2, 3}
# 6001 -> Broadcasting message type: new_transaction
# 6000 -> Transaction message ID: 3 already visited
# 6000 -> Transaction message ID: 3 already visited
# 6002 -> Transaction message ID: 3 already visited
# 6000 -> Transaction message ID: 3 already visited
# 6000 -> Transaction message ID: 3 already visited
# Mining new block to include transaction...
# 6003 -> Leader: 6003
# Mining new block to include transaction...
# 6002 -> Leader: 6003
# Mining new block to include transaction...
# 6004 -> Leader: 6003
# Mining new block to include transaction...
# 6005 -> Leader: 6003

# %%
active_nodes[6000][1].do_sval("")
# Out:
# Messaged ID: {1, 2, 3}
# Messaged ID: {1, 2, 3, 4}
# Broadcasting message type: store_validators
# Messaged ID: {1, 2, 3, 4}
# Messaged ID: {1, 2, 3, 4, 5}
# Broadcasting message type: store_validators

# %%
active_nodes[6000][1].do_val("")
# Out:
# Validators: {6002, 6003, 6004, 6005}

# %%
active_nodes[6004][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733640789
#   Data: Genesis Block
#   Hash: d139e43f8e953e13a45e9581a5ae629693f68f0402f71885566920dfd70f3133
#   Previous Hash: 0
#   Mined by: None

# %%
a = set()
a.add((1, 'po'))

# %%
a.add((2, 'po'))
a.add((2, 'pa'))

# %%
max(a)
# Out:
# (2, 'po')

# %%
import poch as poch
import threading
import time
def run_node(port, address = '127.0.0.1', algo = poch):
    print(f"Running node on port {port}, address: {address}")
    node = algo.Node(address, port)
    cli = algo.NodeCLI(node)
    
    node_thread = threading.Thread(target=node.start)
    node_thread.start()
    
    return node, cli

nodes = [6000 + i for i in range(6)]
edges = [(6000, 6002), (6000, 6003), (6000, 6004), (6000, 6005), (6001, 6002)]

active_nodes = {node : run_node(node, algo = poch) for node in nodes}
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)
# Out:
# Running node on port 6000, address: 127.0.0.1
# Running node on port 6001, address: 127.0.0.1
# Running node on port 6002, address: 127.0.0.1
# Running node on port 6003, address: 127.0.0.1
# Running node on port 6004, address: 127.0.0.1
# Running node on port 6005, address: 127.0.0.1

# %%
active_nodes[6000][1].do_cval("")

# %%
active_nodes[6000][1].do_addtx("user1 10")
# Out:
# -----------------
# 77676224541010851515592811919507999449883271260082503287446600775079474534010
# 94912842579550052562592720653644935062726254309632722634524406694984734364235
# 92847109078483149469832578784291198055760443476375658263924979529891557282364
# 7608326177217803400236988336096838580394771410891922895551635043628360133578
# 28765495133175647291530177456821843357752003512228663003546493269212951385354
# 48952561488371557086385664142527155110420350750510940618616800713074254812867
# 115792089237316195423570985008687907853269984665640564039457584007913129639935 : 6
# -----------------
# -----------------
# 92847109078483149469832578784291198055760443476375658263924979529891557282364
# 94912842579550052562592720653644935062726254309632722634524406694984734364235
# 77676224541010851515592811919507999449883271260082503287446600775079474534010
# 7608326177217803400236988336096838580394771410891922895551635043628360133578
# 28765495133175647291530177456821843357752003512228663003546493269212951385354
# 48952561488371557086385664142527155110420350750510940618616800713074254812867
# 115792089237316195423570985008687907853269984665640564039457584007913129639935 : 6
# -----------------
# -----------------
# 7608326177217803400236988336096838580394771410891922895551635043628360133578
# 94912842579550052562592720653644935062726254309632722634524406694984734364235
# 77676224541010851515592811919507999449883271260082503287446600775079474534010
# 92847109078483149469832578784291198055760443476375658263924979529891557282364
# 28765495133175647291530177456821843357752003512228663003546493269212951385354
# 48952561488371557086385664142527155110420350750510940618616800713074254812867
# 115792089237316195423570985008687907853269984665640564039457584007913129639935 : 6
# -----------------
# 6
# -----------------
# 48952561488371557086385664142527155110420350750510940618616800713074254812867
# 28765495133175647291530177456821843357752003512228663003546493269212951385354
# 94912842579550052562592720653644935062726254309632722634524406694984734364235
# 77676224541010851515592811919507999449883271260082503287446600775079474534010
# 92847109078483149469832578784291198055760443476375658263924979529891557282364
# 7608326177217803400236988336096838580394771410891922895551635043628360133578
# 115792089237316195423570985008687907853269984665640564039457584007913129639935 : 6
# -----------------
# -----------------
# 28765495133175647291530177456821843357752003512228663003546493269212951385354
# 94912842579550052562592720653644935062726254309632722634524406694984734364235
# 48952561488371557086385664142527155110420350750510940618616800713074254812867
# 77676224541010851515592811919507999449883271260082503287446600775079474534010
# 92847109078483149469832578784291198055760443476375658263924979529891557282364
# 7608326177217803400236988336096838580394771410891922895551635043628360133578
# 115792089237316195423570985008687907853269984665640564039457584007913129639935 : 6
# -----------------
# -----------------
# 111517061536066135181699178098046526168012086701038912863737655353595787967210
# 9304096722115975883172210515383564612480066611468672782615531694633837435725
# 78333661331786238545995464615300612998986954234507953092880967094745430107798
# 2191265878328586953612578254822168973166870482400525149953997843243541734430
# 61202620015339665105139858044170116735857521611189354461473242173610161204752
# 2777981499422236530286667604751140820291065361780433588742008018830332805898
# 1.3701616114902216e+77 : 6
# -----------------
# 6

# %%
active_nodes[6000][1].do_cand("")
# Out:
# {6000: 'a9fe9f84802ca70128cfabf87d7f556ec541a145ed0509c6436ca65d6c37f728', 6004: '2eeea98d45fe2e1ca7e8e80ac9e7947694d2b704c308aa58074191a73c5881cc', 6003: '033a19cff4ee3322b0e4d033aedc4b28ead352bd65d1a17e460f0f8c8a8b5f3f', 6005: '591ce28450a6c4deb85796410e3a58b8caa417ef6e34f0e27e82983070c826e0', 6002: 'af811530bec2acac4b083ae81648ee7866692cc652c23f189f2d7ec36d0e88c5', 6001: '5d604fda312f0d50610d28b7af5c667c815e96341ce1b3992a0db3f0e1bd425b'}

# %%
active_nodes[6002][1].do_listpeers("")
# Out:
# Connected peers:
#   - 127.0.0.1:6000
#   - 127.0.0.1:6001

# %%
active_nodes[6003][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733654632
#   Data: Genesis Block
#   Hash: 340e05886a4a3bc848a72bf25057ba380eecf2afcf3ae8289ae37de5d6334d52
#   Previous Hash: 0
#
# Block 1:
#   Timestamp: 1733654645
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 815544c932e7f89ff2c2e5b146dd645c5328ef60a96bacf905029c4a5b3d51a8
#   Previous Hash: 340e05886a4a3bc848a72bf25057ba380eecf2afcf3ae8289ae37de5d6334d52

# %%
# Out:
# 11579208923731619542357098500868790785326998466564056403945758400791312963993500000
