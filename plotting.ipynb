nodes and 10 miners
--------------------------------------------------
Algorithm      Throughput    Latency    CPU Usage    Memory Usage
-----------  ------------  ---------  -----------  --------------
mAASC            0.530659    1.88445         90.6         38.2383
--------------------------------------------------



Number of Nodes: 40, Number of Miners: 10, Number of transaction: 100
Test Results for 40 nodes and 10 miners
--------------------------------------------------
Algorithm      Throughput    Latency    CPU Usage    Memory Usage
-----------  ------------  ---------  -----------  --------------
mAASC            0.355982    2.80913        129.8         49.0664
--------------------------------------------------



Number of Nodes: 50, Number of Miners: 10, Number of transaction: 100
Test Results for 50 nodes and 10 miners
--------------------------------------------------
Algorithm      Throughput    Latency    CPU Usage    Memory Usage
-----------  ------------  ---------  -----------  --------------
mAASC            0.223396    4.47635        184.5         62.0859
--------------------------------------------------



Number of Nodes: 75, Number of Miners: 15, Number of transaction: 100
Test Results for 75 nodes and 15 miners
--------------------------------------------------
Algorithm      Throughput    Latency    CPU Usage    Memory Usage
-----------  ------------  ---------  -----------  --------------
mAASC            0.128409     7.7876        231.9         90.1406
--------------------------------------------------



Number of Nodes: 100, Number of Miners: 20, Number of transaction: 100
Test Results for 100 nodes and 20 miners
--------------------------------------------------
Algorithm      Throughput    Latency    CPU Usage    Memory Usage
-----------  ------------  ---------  -----------  --------------
mAASC           0.0940462    10.6331        251.4         92.5039
--------------------------------------------------

'''
# Out:
# "'Number of Nodes: 10, Number of Miners: 10, Number of transaction: 100\nTest Results for 10 nodes and 10 miners\n--------------------------------------------------\nAlgorithm      Throughput    Latency    CPU Usage    Memory Usage\n-----------  ------------  ---------  -----------  --------------\nPOS              0.917726  1.08965            3.3        1.73438\nPOCH             0.958493  1.0433             2.8       11.1875\nPoEM             2.57249   0.388729           8         10.7852\nAASC            18.4388    0.0542335          2.7        0.609375\n--------------------------------------------------\n',\n '\n',\n '\n',\n '\n',\n 'Number of Nodes: 20, Number of Miners: 10, Number of transaction: 100\nTest Results for 20 nodes and 10 miners\n--------------------------------------------------\nAlgorithm      Throughput    Latency    CPU Usage    Memory Usage\n-----------  ------------  ---------  -----------  --------------\nPOS              0.746223   1.34008          21.6      
# ...

# %%
# Thoroughput values
pos = [0.917726, 0.746223, 0.555474, 0.413795, 0.33751, 0.227378, 0.167438]
poch = [0.958493, 0.849446, 0.609727, 0.483344, 0.38964, 0.278441, 0.215923]
poem = [2.57249, 0.592797, 0.289431, 0.196078, 0.153955, 0.0815647, 0.0484304]
# aasc = [18.4388, 4.19075, 2.87229, 3.07151, 1.99701, 0.469273, 0.536665]
maasc = [7.18794, 1.6881, 0.530659, 0.355982, 0.223396, 0.128409, 0.0940462]

# plotting
plt.plot(pos,'o-',label='POS')
plt.plot(poch,'o-',label='POCH')
plt.plot(poem,'o-',label='PoEM')
# plt.plot(aasc,'o-',label='AASC')
plt.plot(maasc,'o-',label='mAASC')
plt.xlabel('Number of Nodes')
plt.ylabel('Throughput')
plt.xticks(np.arange(7), ('10', '20', '30', '40', '50', '75', '100'))
plt.title('Number of Nodes vs Throughput')
plt.grid()
plt.legend()
plt.show()

# %%
# Latency values
pos = [1.08965, 1.34008, 1.80026, 2.41665, 2.96287, 4.39795, 5.97234]
poch = [1.0433, 1.17724, 1.64008, 2.06892, 2.56647, 3.59142, 4.63129]
poem = [0.388729, 1.68692, 3.45505, 5.10001, 6.49542, 12.2602, 20.6482]
# aasc = [0.0542335, 0.238621, 0.348154, 0.325573, 0.500749, 2.13096, 1.86336]
maasc = [0.139122, 0.592382, 1.88445, 2.80913, 4.47635, 7.7876, 10.6331]

# plotting
plt.plot(pos,'o-',label='POS')
plt.plot(poch,'o-',label='POCH')
plt.plot(poem,'o-',label='PoEM')
# plt.plot(aasc,'o-',label='AASC')
plt.plot(maasc,'o-',label='mAASC')
plt.xlabel('Number of Nodes')
plt.ylabel('Latency')
plt.xticks(np.arange(7), ('10', '20', '30', '40', '50', '75', '100'))
plt.title('Number of Nodes vs Latency')
plt.grid()
plt.legend()
plt.show()

# %%
# CPU Usage values
pos = [3.3, 21.6, 59.1, 92.8, 111.2, 116.6, 159.5]
poch = [2.8, 14.2, 56.4, 87.2, 113.6, 118.7, 131]
poem = [8, 49.6, 81.4, 83.8, 93.1, 53.7, 69.8]
# aasc = [2.7, 10, 27.1, 9.3, 28.7, 111.5, 75.2]
maasc = [5.3, 49.4, 90.6, 129.8, 184.5, 231.9, 251.4]

# plotting
plt.plot(pos,'o-',label='POS')
plt.plot(poch,'o-',label='POCH')
plt.plot(poem,'o-',label='PoEM')
# plt.plot(aasc,'o-',label='AASC')
plt.plot(maasc,'o-',label='mAASC')
plt.xlabel('Number of Nodes')
plt.ylabel('CPU Usage')
plt.xticks(np.arange(7), ('10', '20', '30', '40', '50', '75', '100'))
plt.title('Number of Nodes vs CPU Usage')
plt.grid()
plt.legend()
plt.show()

# %%
# Memory Usage values
pos = [1.73438, 12.8164, 27.2539, 35.9883, 41.707, 79.6953, 86.875]
poch = [11.1875, 20.1523, 39.5234, 45.1562, 61.4141, 88.3359, 133.426]
poem = [10.7852, 21.3477, 35.9297, 57.2461, 66.8438, 104.309, 127.176]
# aasc = [0.609375, 11.7266, 25.7852, 36.1719, 45.8945, 77.375, 101.926]
maasc = [13.4492, 19.1094, 38.2383, 49.0664, 62.0859, 90.1406, 92.5039]

# plotting
plt.plot(pos,'o-',label='POS')
plt.plot(poch,'o-',label='POCH')
plt.plot(poem,'o-',label='PoEM')
# plt.plot(aasc,'o-',label='AASC')
plt.plot(maasc,'o-',label='mAASC')
plt.xlabel('Number of Nodes')
plt.ylabel('Memory Usage')
plt.xticks(np.arange(7), ('10', '20', '30', '40', '50', '75', '100'))
plt.title('Number of Nodes vs Memory Usage')
plt.grid()
plt.legend()
plt.show()
