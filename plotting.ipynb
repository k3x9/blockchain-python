# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('result.txt', 'r') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['Number of Nodes: 10, Number of Miners: 2, Number of transaction: 500\n',
#  'Test Results for 10 nodes and 2 miners\n',
#  '--------------------------------------------------\n',
#  'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',
#  '-----------  ------------  ---------  -----------  --------------\n',
#  'AASC             0.529869   1.88726           6.1        1.34375\n',
#  'PoEM             0.996298   1.00372          69.6       10.25\n',
#  'POS              2.31002    0.432897        153.5       -0.660156\n',
#  '--------------------------------------------------\n',
#  '\n',
#  '\n',
#  '\n',
#  'Number of Nodes: 20, Number of Miners: 4, Number of transaction: 500\n',
#  'Test Results for 20 nodes and 4 miners\n',
#  '--------------------------------------------------\n',
#  'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',
#  '-----------  ------------  ---------  -----------  --------------\n',
# ...

# %%
''''--------------------------------------------------\n',
 'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',
 '-----------  ------------  ---------  -----------  --------------\n',
 'POS              0.549399   1.82017         121.5       -0.792969\n',
 'POCH             0.686762   1.45611         101.1       10.0156\n',
 'PoEM             0.329444   3.03542         214.3        2.08984\n',
 'AASC             2.42826    0.411817         65.5        3.42578\n',
 '--------------------------------------------------\n',
 '\n',
 '\n',
 '\n',
 'Number of Nodes: 30, Number of Miners: 10, Number of transaction: 100\n',
 'Test Results for 30 nodes and 10 miners\n',
 '--------------------------------------------------\n',
 'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',
 '-----------  ------------  ---------  -----------  --------------\n',
 'POS              0.197582    5.06118        114.8         0.59375\n',
 'POCH             0.319099    3.13382        235.3         3.82031\n',
 'PoEM             0.101526    9.84967        280.4         9.13281\n',
 'AASC             0.807676    1.23812        154.4         5.74609\n',
 '--------------------------------------------------\n',
 '\n',
 '\n',
 '\n',
 'Number of Nodes: 40, Number of Miners: 10, Number of transaction: 100\n',
 'Test Results for 40 nodes and 10 miners\n',
 '--------------------------------------------------\n',
 'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',
 '-----------  ------------  ---------  -----------  --------------\n',
 'POS             0.15055      6.64231        139.2        0.265625\n',
 'POCH            0.212318     4.70991        261.6       -0.113281\n',
 'PoEM            0.0693465   14.4203         299.1        8.17188\n',
 'AASC            0.560078     1.78547        171.8        9.92578\n',
 '--------------------------------------------------\n',
 '\n',
 '\n',
 '\n',
 'Number of Nodes: 50, Number of Miners: 10, Number of transaction: 100\n',
 'Test Results for 50 nodes and 10 miners\n',
 '--------------------------------------------------\n',
 'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',
 '-----------  ------------  ---------  -----------  --------------\n',
 'POS             0.112644     8.8775         143.8         2.63281\n',
 'POCH            0.176665     5.66042        286.6         3.48828\n',
 'PoEM            0.0526535   18.9921         267.8         9.40234\n',
 'AASC            0.402223     2.48618        199.5         5.25391\n',
 '--------------------------------------------------\n','''
# Out:
# "'--------------------------------------------------\n',\n 'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',\n '-----------  ------------  ---------  -----------  --------------\n',\n 'POS              0.549399   1.82017         121.5       -0.792969\n',\n 'POCH             0.686762   1.45611         101.1       10.0156\n',\n 'PoEM             0.329444   3.03542         214.3        2.08984\n',\n 'AASC             2.42826    0.411817         65.5        3.42578\n',\n '--------------------------------------------------\n',\n '\n',\n '\n',\n '\n',\n 'Number of Nodes: 30, Number of Miners: 10, Number of transaction: 100\n',\n 'Test Results for 30 nodes and 10 miners\n',\n '--------------------------------------------------\n',\n 'Algorithm      Throughput    Latency    CPU Usage    Memory Usage\n',\n '-----------  ------------  ---------  -----------  --------------\n',\n 'POS              0.197582    5.06118        114.8         0.59375\n',\n 'POCH             0.31
# ...

# %%
pos = [0.549399, 0.197582, 0.15055, 0.112644]
poch = [0.686762, 0.319099, 0.212318, 0.176665]
poem = [0.329444, 0.101526, 0.0693465, 0.0526535]
aasc = [2.42826, 0.807676, 0.560078, 0.402223]

# plotting
plt.plot(pos,'o' label='POS')
plt.plot(poch, label='POCH')
plt.plot(poem, label='PoEM')
plt.plot(aasc, label='AASC')
plt.xlabel('Number of Nodes')
plt.ylabel('Throughput')
plt.title('Throughput vs Number of Nodes')
plt.legend()
plt.grid()
plt.xticks(np.arange(4), ('20', '30', '40', '50'))
plt.show()
